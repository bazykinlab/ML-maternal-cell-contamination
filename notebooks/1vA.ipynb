# %%
import pandas as pd
import numpy as np

import sys
sys.path.insert(0, '../python')
from preprocessing import load_suffixes, prepare_input
from recalibrator import Recalibrator
from utils import match

np.random.seed(64)

# %%
trios = ["ajt", "chd", "corpas", "yri"]

# Pre-processing. Uncomment during first run of the script, then
# comment to avoid re-computing

for trio in trios:
    data_dir = '../data/' + trio + '/'
    df = load_suffixes(data_dir)
    df.to_csv(trio + '.csv', index=False)
# Out:
# 100%|██████████| 12/12 [01:51<00:00,  9.06s/it]
# 100%|██████████| 12/12 [01:36<00:00,  8.37s/it]
# 100%|██████████| 12/12 [01:35<00:00,  7.98s/it]
# 100%|██████████| 12/12 [02:19<00:00, 11.49s/it]

# %% [markdown]
# For each trio, construct a training set from the remaining trios and save the predictions into a dictionary.

# %%
results_cum = {}

for test in trios:
    results = {}
    df_train = pd.DataFrame()
    
    for train in trios:
        if train != test:
            df_train = df_train.append(pd.read_csv(train + '.csv'))

    df_train = df_train[::100]
    df_test = pd.read_csv(test + '.csv')    
    
    X_train = prepare_input(df_train, target_cols=['justchild^GT'])
    y_train = df_train['justchild^GT'].values
    X_test = prepare_input(df_test, target_cols=['justchild^GT'])
    y_test = df_test['justchild^GT'].values

    contaminations = df_test['contamination'].values
    contamination_values = list(sorted(np.unique(contaminations)))

    X_tests = {}
    y_tests = {}
    idx = {}

    for contamination in contamination_values:
        idx[contamination] = contaminations == contamination
        X_tests[contamination] = X_test[idx[contamination]]
        y_tests[contamination] = y_test[idx[contamination]]
    
    results['dp'] = df_test['abortus^DP'].values
    results['y_test'] = y_test
    results['preds_naive'] = df_test['abortus^GT'].values
    results['idx'] = idx

    r = Recalibrator()
    print(test)
    r.train(X_train, y_train)
    
    results['preds_meta'] = r.model_meta.predict(X_test)
    results['probs'] = r.model_meta.predict_proba(X_test)
    results['preds_lr'] = r.predict_lr(X_test)
    results['preds_xgb'] = r.predict_xgb(X_test)
#     results['preds_ci'] = r.model_ci.predict(X_test)
    results['preds_mle'] = r.model_mle.predict(X_test)

    results_cum[test] = results
# Out:
# ajt
# Training logistic regression
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.064502
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.05724
# [2]	validation_0-merror:0.058095
# [3]	validation_0-merror:0.058522
# [4]	validation_0-merror:0.058949
# [5]	validation_0-merror:0.057668
# [6]	validation_0-merror:0.055532
# [7]	validation_0-merror:0.052969
# [8]	validation_0-merror:0.052969
# [9]	validation_0-merror:0.052542
# [10]	validation_0-merror:0.052114
# [11]	validation_0-merror:0.050406
# [12]	validation_0-merror:0.048697
# [13]	validation_0-merror:0.049124
# [14]	validation_0-merror:0.049124
# [15]	validation_0-merror:0.04827
# [16]	validation_0-merror:0.048697
# [17]	validation_0-merror:0.047843
# [18]	validation_0-merror:0.046134
# [19]	validation_0-merror:0.045707
# [20]	validation_0-merror:0.04528
# [21]	validation_0-merror:0.045707
# [22]	validation_0-merror:0.044425
# [23]	validation_0-merror:0.044425
# [24]	validation_0-merror:0.043144
# [25]	validation_0-merror:0.043998
# [26]	validation_0-merror:0.041862
# [27]	validation_0-merror:0.041862
# [28]	validation_0-merror:0.041435
# [29]	validation_0-merror:0.041008
# [30]	validation_0-merror:0.040581
# [31]	validation_0-merror:0.041008
# [32]	validation_0-merror:0.041008
# [33]	validation_0-merror:0.041435
# [34]	validation_0-merror:0.041435
# [35]	validation_0-merror:0.041435
# [36]	validation_0-merror:0.041435
# [37]	validation_0-merror:0.041008
# [38]	validation_0-merror:0.041008
# [39]	validation_0-merror:0.040581
# [40]	validation_0-merror:0.040581
# [41]	validation_0-merror:0.040581
# [42]	validation_0-merror:0.040581
# [43]	validation_0-merror:0.039727
# [44]	validation_0-merror:0.038872
# [45]	validation_0-merror:0.038018
# [46]	validation_0-merror:0.038018
# [47]	validation_0-merror:0.038018
# [48]	validation_0-merror:0.038445
# [49]	validation_0-merror:0.038445
# [50]	validation_0-merror:0.038445
# [51]	validation_0-merror:0.038018
# [52]	validation_0-merror:0.037591
# [53]	validation_0-merror:0.037164
# [54]	validation_0-merror:0.035455
# [55]	validation_0-merror:0.035882
# [56]	validation_0-merror:0.036309
# [57]	validation_0-merror:0.036309
# [58]	validation_0-merror:0.036309
# [59]	validation_0-merror:0.036309
# [60]	validation_0-merror:0.036736
# [61]	validation_0-merror:0.036736
# [62]	validation_0-merror:0.037164
# [63]	validation_0-merror:0.036736
# [64]	validation_0-merror:0.036736
# [65]	validation_0-merror:0.036736
# [66]	validation_0-merror:0.036736
# [67]	validation_0-merror:0.036736
# [68]	validation_0-merror:0.036309
# [69]	validation_0-merror:0.037164
# [70]	validation_0-merror:0.036736
# [71]	validation_0-merror:0.038018
# [72]	validation_0-merror:0.038445
# [73]	validation_0-merror:0.038445
# [74]	validation_0-merror:0.037591
# Stopping. Best iteration:
# [54]	validation_0-merror:0.035455
#
# Training meta-classifier
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# chd
# Training logistic regression
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.047292
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.046079
# [2]	validation_0-merror:0.037187
# [3]	validation_0-merror:0.040016
# [4]	validation_0-merror:0.036783
# [5]	validation_0-merror:0.034762
# [6]	validation_0-merror:0.034762
# [7]	validation_0-merror:0.035974
# [8]	validation_0-merror:0.03557
# [9]	validation_0-merror:0.034762
# [10]	validation_0-merror:0.034357
# [11]	validation_0-merror:0.034762
# [12]	validation_0-merror:0.034357
# [13]	validation_0-merror:0.033549
# [14]	validation_0-merror:0.033549
# [15]	validation_0-merror:0.033549
# [16]	validation_0-merror:0.03274
# [17]	validation_0-merror:0.031124
# [18]	validation_0-merror:0.031528
# [19]	validation_0-merror:0.031528
# [20]	validation_0-merror:0.031528
# [21]	validation_0-merror:0.030315
# [22]	validation_0-merror:0.029911
# [23]	validation_0-merror:0.029911
# [24]	validation_0-merror:0.029103
# [25]	validation_0-merror:0.028698
# [26]	validation_0-merror:0.029911
# [27]	validation_0-merror:0.028698
# [28]	validation_0-merror:0.028294
# [29]	validation_0-merror:0.027486
# [30]	validation_0-merror:0.028294
# [31]	validation_0-merror:0.02789
# [32]	validation_0-merror:0.027082
# [33]	validation_0-merror:0.026677
# [34]	validation_0-merror:0.027082
# [35]	validation_0-merror:0.026273
# [36]	validation_0-merror:0.026677
# [37]	validation_0-merror:0.026677
# [38]	validation_0-merror:0.025869
# [39]	validation_0-merror:0.025869
# [40]	validation_0-merror:0.026677
# [41]	validation_0-merror:0.027082
# [42]	validation_0-merror:0.027082
# [43]	validation_0-merror:0.026677
# [44]	validation_0-merror:0.026273
# [45]	validation_0-merror:0.026677
# [46]	validation_0-merror:0.026273
# [47]	validation_0-merror:0.025869
# [48]	validation_0-merror:0.025465
# [49]	validation_0-merror:0.025869
# [50]	validation_0-merror:0.025869
# [51]	validation_0-merror:0.025465
# [52]	validation_0-merror:0.025465
# [53]	validation_0-merror:0.025061
# [54]	validation_0-merror:0.025061
# [55]	validation_0-merror:0.025061
# [56]	validation_0-merror:0.025061
# [57]	validation_0-merror:0.025061
# [58]	validation_0-merror:0.025061
# [59]	validation_0-merror:0.024656
# [60]	validation_0-merror:0.024656
# [61]	validation_0-merror:0.024252
# [62]	validation_0-merror:0.024252
# [63]	validation_0-merror:0.024252
# [64]	validation_0-merror:0.024252
# [65]	validation_0-merror:0.023848
# [66]	validation_0-merror:0.023848
# [67]	validation_0-merror:0.024252
# [68]	validation_0-merror:0.024252
# [69]	validation_0-merror:0.023848
# [70]	validation_0-merror:0.023848
# [71]	validation_0-merror:0.023848
# [72]	validation_0-merror:0.024252
# [73]	validation_0-merror:0.024252
# [74]	validation_0-merror:0.024252
# [75]	validation_0-merror:0.024252
# [76]	validation_0-merror:0.024656
# [77]	validation_0-merror:0.024656
# [78]	validation_0-merror:0.024656
# [79]	validation_0-merror:0.024656
# [80]	validation_0-merror:0.024656
# [81]	validation_0-merror:0.025061
# [82]	validation_0-merror:0.024656
# [83]	validation_0-merror:0.025061
# [84]	validation_0-merror:0.025061
# [85]	validation_0-merror:0.025061
# Stopping. Best iteration:
# [65]	validation_0-merror:0.023848
#
# Training meta-classifier
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# corpas
# Training logistic regression
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.053264
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.054065
# [2]	validation_0-merror:0.052062
# [3]	validation_0-merror:0.048458
# [4]	validation_0-merror:0.049259
# [5]	validation_0-merror:0.047257
# [6]	validation_0-merror:0.047657
# [7]	validation_0-merror:0.046456
# [8]	validation_0-merror:0.046856
# [9]	validation_0-merror:0.046456
# [10]	validation_0-merror:0.047257
# [11]	validation_0-merror:0.045655
# [12]	validation_0-merror:0.044453
# [13]	validation_0-merror:0.044053
# [14]	validation_0-merror:0.044053
# [15]	validation_0-merror:0.043652
# [16]	validation_0-merror:0.043652
# [17]	validation_0-merror:0.042851
# [18]	validation_0-merror:0.04165
# [19]	validation_0-merror:0.041249
# [20]	validation_0-merror:0.039648
# [21]	validation_0-merror:0.039247
# [22]	validation_0-merror:0.038446
# [23]	validation_0-merror:0.038847
# [24]	validation_0-merror:0.039247
# [25]	validation_0-merror:0.038446
# [26]	validation_0-merror:0.037645
# [27]	validation_0-merror:0.037245
# [28]	validation_0-merror:0.036444
# [29]	validation_0-merror:0.035643
# [30]	validation_0-merror:0.036043
# [31]	validation_0-merror:0.035242
# [32]	validation_0-merror:0.035242
# [33]	validation_0-merror:0.036043
# [34]	validation_0-merror:0.034842
# [35]	validation_0-merror:0.034441
# [36]	validation_0-merror:0.034041
# [37]	validation_0-merror:0.034842
# [38]	validation_0-merror:0.034041
# [39]	validation_0-merror:0.034441
# [40]	validation_0-merror:0.035242
# [41]	validation_0-merror:0.034842
# [42]	validation_0-merror:0.034842
# [43]	validation_0-merror:0.036043
# [44]	validation_0-merror:0.035242
# [45]	validation_0-merror:0.034441
# [46]	validation_0-merror:0.034441
# [47]	validation_0-merror:0.03364
# [48]	validation_0-merror:0.034441
# [49]	validation_0-merror:0.034041
# [50]	validation_0-merror:0.034041
# [51]	validation_0-merror:0.03364
# [52]	validation_0-merror:0.03324
# [53]	validation_0-merror:0.032839
# [54]	validation_0-merror:0.032839
# [55]	validation_0-merror:0.032839
# [56]	validation_0-merror:0.032038
# [57]	validation_0-merror:0.031638
# [58]	validation_0-merror:0.031638
# [59]	validation_0-merror:0.031237
# [60]	validation_0-merror:0.031237
# [61]	validation_0-merror:0.032038
# [62]	validation_0-merror:0.032038
# [63]	validation_0-merror:0.031638
# [64]	validation_0-merror:0.031638
# [65]	validation_0-merror:0.030837
# [66]	validation_0-merror:0.031237
# [67]	validation_0-merror:0.030437
# [68]	validation_0-merror:0.030437
# [69]	validation_0-merror:0.030437
# [70]	validation_0-merror:0.030437
# [71]	validation_0-merror:0.031237
# [72]	validation_0-merror:0.030837
# [73]	validation_0-merror:0.031638
# [74]	validation_0-merror:0.030036
# [75]	validation_0-merror:0.030437
# [76]	validation_0-merror:0.030837
# [77]	validation_0-merror:0.030837
# [78]	validation_0-merror:0.030036
# [79]	validation_0-merror:0.030437
# [80]	validation_0-merror:0.030837
# [81]	validation_0-merror:0.030837
# [82]	validation_0-merror:0.030837
# [83]	validation_0-merror:0.030837
# [84]	validation_0-merror:0.030437
# [85]	validation_0-merror:0.030036
# [86]	validation_0-merror:0.030036
# [87]	validation_0-merror:0.029636
# [88]	validation_0-merror:0.030437
# [89]	validation_0-merror:0.029235
# [90]	validation_0-merror:0.028835
# [91]	validation_0-merror:0.029235
# [92]	validation_0-merror:0.028835
# [93]	validation_0-merror:0.029235
# [94]	validation_0-merror:0.029235
# [95]	validation_0-merror:0.029636
# [96]	validation_0-merror:0.029636
# [97]	validation_0-merror:0.029235
# [98]	validation_0-merror:0.030036
# [99]	validation_0-merror:0.029636
# [100]	validation_0-merror:0.029636
# [101]	validation_0-merror:0.030036
# [102]	validation_0-merror:0.030837
# [103]	validation_0-merror:0.031237
# [104]	validation_0-merror:0.030837
# [105]	validation_0-merror:0.030437
# [106]	validation_0-merror:0.030437
# [107]	validation_0-merror:0.030837
# [108]	validation_0-merror:0.029636
# [109]	validation_0-merror:0.029235
# [110]	validation_0-merror:0.029235
# Stopping. Best iteration:
# [90]	validation_0-merror:0.028835
#
# Training meta-classifier
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# yri
# Training logistic regression
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.051628
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.046047
# [2]	validation_0-merror:0.049767
# [3]	validation_0-merror:0.049767
# [4]	validation_0-merror:0.047907
# [5]	validation_0-merror:0.048372
# [6]	validation_0-merror:0.047442
# [7]	validation_0-merror:0.046977
# [8]	validation_0-merror:0.046977
# [9]	validation_0-merror:0.045581
# [10]	validation_0-merror:0.044651
# [11]	validation_0-merror:0.044651
# [12]	validation_0-merror:0.045116
# [13]	validation_0-merror:0.044186
# [14]	validation_0-merror:0.044651
# [15]	validation_0-merror:0.044651
# [16]	validation_0-merror:0.045116
# [17]	validation_0-merror:0.044186
# [18]	validation_0-merror:0.043721
# [19]	validation_0-merror:0.043256
# [20]	validation_0-merror:0.042791
# [21]	validation_0-merror:0.043256
# [22]	validation_0-merror:0.042791
# [23]	validation_0-merror:0.043721
# [24]	validation_0-merror:0.043721
# [25]	validation_0-merror:0.042791
# [26]	validation_0-merror:0.043721
# [27]	validation_0-merror:0.044186
# [28]	validation_0-merror:0.044186
# [29]	validation_0-merror:0.044186
# [30]	validation_0-merror:0.042791
# [31]	validation_0-merror:0.043721
# [32]	validation_0-merror:0.042791
# [33]	validation_0-merror:0.043256
# [34]	validation_0-merror:0.042326
# [35]	validation_0-merror:0.04186
# [36]	validation_0-merror:0.04093
# [37]	validation_0-merror:0.04093
# [38]	validation_0-merror:0.040465
# [39]	validation_0-merror:0.041395
# [40]	validation_0-merror:0.041395
# [41]	validation_0-merror:0.04186
# [42]	validation_0-merror:0.040465
# [43]	validation_0-merror:0.040465
# [44]	validation_0-merror:0.040465
# [45]	validation_0-merror:0.04
# [46]	validation_0-merror:0.041395
# [47]	validation_0-merror:0.04093
# [48]	validation_0-merror:0.04093
# [49]	validation_0-merror:0.04093
# [50]	validation_0-merror:0.04093
# [51]	validation_0-merror:0.04093
# [52]	validation_0-merror:0.04186
# [53]	validation_0-merror:0.04
# [54]	validation_0-merror:0.04
# [55]	validation_0-merror:0.039535
# [56]	validation_0-merror:0.040465
# [57]	validation_0-merror:0.040465
# [58]	validation_0-merror:0.039535
# [59]	validation_0-merror:0.039535
# [60]	validation_0-merror:0.04
# [61]	validation_0-merror:0.039535
# [62]	validation_0-merror:0.039535
# [63]	validation_0-merror:0.04
# [64]	validation_0-merror:0.039535
# [65]	validation_0-merror:0.039535
# [66]	validation_0-merror:0.03907
# [67]	validation_0-merror:0.03907
# [68]	validation_0-merror:0.03907
# [69]	validation_0-merror:0.039535
# [70]	validation_0-merror:0.03907
# [71]	validation_0-merror:0.03907
# [72]	validation_0-merror:0.03907
# [73]	validation_0-merror:0.03907
# [74]	validation_0-merror:0.03907
# [75]	validation_0-merror:0.03907
# [76]	validation_0-merror:0.03907
# [77]	validation_0-merror:0.039535
# [78]	validation_0-merror:0.03907
# [79]	validation_0-merror:0.039535
# [80]	validation_0-merror:0.03907
# [81]	validation_0-merror:0.03907
# [82]	validation_0-merror:0.039535
# [83]	validation_0-merror:0.03907
# [84]	validation_0-merror:0.038605
# [85]	validation_0-merror:0.03814
# [86]	validation_0-merror:0.038605
# [87]	validation_0-merror:0.03907
# [88]	validation_0-merror:0.03907
# [89]	validation_0-merror:0.039535
# [90]	validation_0-merror:0.03907
# [91]	validation_0-merror:0.03907
# [92]	validation_0-merror:0.03907
# [93]	validation_0-merror:0.03907
# [94]	validation_0-merror:0.03907
# [95]	validation_0-merror:0.03907
# [96]	validation_0-merror:0.03907
# [97]	validation_0-merror:0.03907
# [98]	validation_0-merror:0.039535
# [99]	validation_0-merror:0.04
# [100]	validation_0-merror:0.039535
# [101]	validation_0-merror:0.03907
# [102]	validation_0-merror:0.039535
# [103]	validation_0-merror:0.03907
# [104]	validation_0-merror:0.040465
# [105]	validation_0-merror:0.04093
# Stopping. Best iteration:
# [85]	validation_0-merror:0.03814
#
# Training meta-classifier
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %% [markdown]
# Serialize and save the dictionary

# %%
import pickle

with open("results_1vA.pickle", "wb") as f:
    pickle.dump(results_cum, f)
