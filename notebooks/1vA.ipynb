# %%
import pandas as pd
from sklearn.metrics import accuracy_score

from preprocessing import load_suffixes, prepare_input
from recalibrator import Recalibrator
from utils import match
from confidence_intervals import confidence_intervals

# %%
trios = ["ajt", "chd", "corpas", "yri"]

# Pre-processing. Uncomment during first run of the script, then
# comment to avoid re-computing

for trio in trios:
    data_dir = '../data/' + trio + '/'
    df = load_suffixes(data_dir)
    df.to_csv(trio + '.csv', index=False)
# Out:
#   0%|          | 0/12 [00:00<?, ?it/s]/home/boi/research/ML-maternal-cell-contamination/python/preprocessing.py:191: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   df = df.convert_objects(convert_numeric=True)
# 100%|██████████| 12/12 [01:24<00:00,  7.07s/it]
# 100%|██████████| 12/12 [01:14<00:00,  6.24s/it]
# 100%|██████████| 12/12 [01:07<00:00,  5.64s/it]
# 100%|██████████| 12/12 [01:42<00:00,  8.55s/it]

# %% [markdown]
# For each trio, construct a training set from the remaining trios and save the predictions into a dictionary.

# %%
results_cum = {}

for test in trios:
    results = {}
    df_train = pd.DataFrame()
    
    for train in trios:
        if train != test:
            df_train = df_train.append(pd.read_csv(train + '.csv'))

    df_test = pd.read_csv(test + '.csv')
    
    X_train = prepare_input(df_train, target_cols=['justchild^GT'])
    y_train = df_train['justchild^GT'].values
    X_test = prepare_input(df_test, target_cols=['justchild^GT'])
    y_test = df_test['justchild^GT'].values

    contaminations = df_test['contamination'].values
    contamination_values = list(sorted(np.unique(contaminations)))

    X_tests = {}
    y_tests = {}
    idx = {}

    for contamination in contamination_values:
        idx[contamination] = contaminations == contamination
        X_tests[contamination] = X_test[idx[contamination]]
        y_tests[contamination] = y_test[idx[contamination]]

    results['y_test'] = y_test
    results['preds_naive'] = df_test['abortus^GT'].values
    results['idx'] = idx

    r = Recalibrator()
    print(test)
    r.train(X_train, y_train)
    
    results['preds_lr'] = r.predict_lr(X_test)
    results['preds_xgb'] = r.predict_xgb(X_test)
    results['preds_ci'] = confidence_intervals(df_test)

    results_cum[test] = results
# Out:
# ajt
# Training logistic regression
# /usr/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.057969
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.053868
# [2]	validation_0-merror:0.052928
# [3]	validation_0-merror:0.052629
# [4]	validation_0-merror:0.052757
# [5]	validation_0-merror:0.051177
# [6]	validation_0-merror:0.051006
# [7]	validation_0-merror:0.049212
# [8]	validation_0-merror:0.047119
# [9]	validation_0-merror:0.046734
# [10]	validation_0-merror:0.045923
# [11]	validation_0-merror:0.045282
# [12]	validation_0-merror:0.044556
# [13]	validation_0-merror:0.043829
# [14]	validation_0-merror:0.043915
# [15]	validation_0-merror:0.043274
# [16]	validation_0-merror:0.042889
# [17]	validation_0-merror:0.042505
# [18]	validation_0-merror:0.041992
# [19]	validation_0-merror:0.04148
# [20]	validation_0-merror:0.041309
# [21]	validation_0-merror:0.040967
# [22]	validation_0-merror:0.041181
# [23]	validation_0-merror:0.040754
# [24]	validation_0-merror:0.040198
# [25]	validation_0-merror:0.039728
# [26]	validation_0-merror:0.039643
# [27]	validation_0-merror:0.039429
# [28]	validation_0-merror:0.039088
# [29]	validation_0-merror:0.038831
# [30]	validation_0-merror:0.038361
# [116]	validation_0-merror:0.03315
# [117]	validation_0-merror:0.03315
# [118]	validation_0-merror:0.033235
# [119]	validation_0-merror:0.033107
# [120]	validation_0-merror:0.033064
# [121]	validation_0-merror:0.033107
# [122]	validation_0-merror:0.033192
# [123]	validation_0-merror:0.03315
# [124]	validation_0-merror:0.033278
# [125]	validation_0-merror:0.033406
# [126]	validation_0-merror:0.033406
# [127]	validation_0-merror:0.033449
# [128]	validation_0-merror:0.033491
# [129]	validation_0-merror:0.033449
# [130]	validation_0-merror:0.033577
# [131]	validation_0-merror:0.033534
# [132]	validation_0-merror:0.033534
# Stopping. Best iteration:
# [112]	validation_0-merror:0.033021
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/boi/research/ML-maternal-cell-contamination/python/confidence_intervals.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   lower_bound = contaminations - z*np.sqrt(contaminations*(1 - contaminations)/df_test[sample_name + '^DP'].values)
# /home/boi/research/ML-maternal-cell-contamination/python/confidence_intervals.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   upper_bound = contaminations + z*np.sqrt(contaminations*(1 - contaminations)/df_test[sample_name + '^DP'].values)
# chd
# Training logistic regression
# /usr/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.033308
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.033833
# [2]	validation_0-merror:0.031529
# [3]	validation_0-merror:0.029993
# [4]	validation_0-merror:0.030317
# [5]	validation_0-merror:0.029346
# [6]	validation_0-merror:0.029063
# [7]	validation_0-merror:0.029063
# [8]	validation_0-merror:0.02874
# [9]	validation_0-merror:0.028376
# [10]	validation_0-merror:0.028498
# [11]	validation_0-merror:0.028417
# [12]	validation_0-merror:0.028174
# [13]	validation_0-merror:0.027366
# [14]	validation_0-merror:0.027042
# [15]	validation_0-merror:0.027083
# [16]	validation_0-merror:0.026921
# [17]	validation_0-merror:0.026719
# [18]	validation_0-merror:0.026557
# [19]	validation_0-merror:0.026193
# [20]	validation_0-merror:0.025911
# [21]	validation_0-merror:0.025547
# [22]	validation_0-merror:0.025506
# [23]	validation_0-merror:0.025183
# [24]	validation_0-merror:0.024819
# [25]	validation_0-merror:0.02494
# [26]	validation_0-merror:0.024738
# [27]	validation_0-merror:0.024819
# [28]	validation_0-merror:0.024738
# [29]	validation_0-merror:0.024496
# [30]	validation_0-merror:0.024213
# [31]	validation_0-merror:0.024213
# [32]	validation_0-merror:0.023809
# [33]	validation_0-merror:0.023606
# [34]	validation_0-merror:0.023526
# [35]	validation_0-merror:0.023283
# [36]	validation_0-merror:0.022919
# [37]	validation_0-merror:0.022919
# [38]	validation_0-merror:0.022838
# [39]	validation_0-merror:0.022353
# [40]	validation_0-merror:0.02207
# [41]	validation_0-merror:0.021828
# [42]	validation_0-merror:0.021707
# [43]	validation_0-merror:0.021747
# [44]	validation_0-merror:0.021505
# [45]	validation_0-merror:0.021545
# [46]	validation_0-merror:0.021464
# [47]	validation_0-merror:0.021181
# [48]	validation_0-merror:0.021019
# [49]	validation_0-merror:0.021141
# [50]	validation_0-merror:0.021141
# [51]	validation_0-merror:0.0211
# [52]	validation_0-merror:0.02106
# [53]	validation_0-merror:0.021181
# [54]	validation_0-merror:0.020979
# [55]	validation_0-merror:0.020939
# [56]	validation_0-merror:0.020898
# [57]	validation_0-merror:0.020736
# [58]	validation_0-merror:0.020696
# [59]	validation_0-merror:0.020656
# [60]	validation_0-merror:0.020656
# [61]	validation_0-merror:0.020615
# [62]	validation_0-merror:0.020575
# [63]	validation_0-merror:0.020534
# [64]	validation_0-merror:0.020656
# [65]	validation_0-merror:0.020615
# [66]	validation_0-merror:0.020494
# [67]	validation_0-merror:0.020494
# [68]	validation_0-merror:0.020454
# [69]	validation_0-merror:0.020332
# [70]	validation_0-merror:0.020332
# [71]	validation_0-merror:0.020292
# [72]	validation_0-merror:0.02013
# [73]	validation_0-merror:0.02013
# [74]	validation_0-merror:0.020171
# [75]	validation_0-merror:0.02013
# [76]	validation_0-merror:0.020171
# [77]	validation_0-merror:0.020211
# [78]	validation_0-merror:0.020171
# [79]	validation_0-merror:0.02013
# [80]	validation_0-merror:0.020049
# [81]	validation_0-merror:0.019888
# [82]	validation_0-merror:0.019888
# [83]	validation_0-merror:0.019726
# [84]	validation_0-merror:0.019766
# [85]	validation_0-merror:0.019605
# [86]	validation_0-merror:0.019686
# [87]	validation_0-merror:0.019645
# [88]	validation_0-merror:0.019726
# [89]	validation_0-merror:0.019766
# [90]	validation_0-merror:0.019645
# [91]	validation_0-merror:0.019686
# [92]	validation_0-merror:0.019686
# [93]	validation_0-merror:0.019726
# [94]	validation_0-merror:0.019645
# [95]	validation_0-merror:0.019726
# [96]	validation_0-merror:0.019807
# [97]	validation_0-merror:0.019726
# [98]	validation_0-merror:0.019726
# [99]	validation_0-merror:0.019726
# [100]	validation_0-merror:0.019645
# [101]	validation_0-merror:0.019645
# [102]	validation_0-merror:0.019605
# [103]	validation_0-merror:0.019483
# [104]	validation_0-merror:0.019483
# [105]	validation_0-merror:0.019403
# [106]	validation_0-merror:0.019362
# [107]	validation_0-merror:0.019443
# [108]	validation_0-merror:0.019443
# [109]	validation_0-merror:0.019524
# [110]	validation_0-merror:0.019483
# [111]	validation_0-merror:0.019443
# [112]	validation_0-merror:0.019483
# [113]	validation_0-merror:0.019403
# [114]	validation_0-merror:0.019443
# [115]	validation_0-merror:0.019443
# [116]	validation_0-merror:0.019605
# [117]	validation_0-merror:0.019686
# [118]	validation_0-merror:0.019686
# [119]	validation_0-merror:0.019564
# [120]	validation_0-merror:0.019564
# [121]	validation_0-merror:0.019524
# [122]	validation_0-merror:0.019403
# [123]	validation_0-merror:0.019483
# [124]	validation_0-merror:0.019524
# [125]	validation_0-merror:0.019564
# [126]	validation_0-merror:0.019564
# Stopping. Best iteration:
# [106]	validation_0-merror:0.019362
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# corpas
# Training logistic regression
# /usr/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.046498
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0
# [93]	validation_0-merror:0.026313
# [94]	validation_0-merror:0.026313
# [95]	validation_0-merror:0.026313
# [96]	validation_0-merror:0.026233
# [97]	validation_0-merror:0.026513
# [98]	validation_0-merror:0.026393
# [99]	validation_0-merror:0.026433
# [100]	validation_0-merror:0.026233
# [101]	validation_0-merror:0.026152
# [102]	validation_0-merror:0.026233
# [103]	validation_0-merror:0.026273
# [104]	validation_0-merror:0.026273
# [105]	validation_0-merror:0.026152
# [106]	validation_0-merror:0.026152
# [107]	validation_0-merror:0.026152
# [108]	validation_0-merror:0.026072
# [109]	validation_0-merror:0.026072
# [110]	validation_0-merror:0.026112
# [111]	validation_0-merror:0.026032
# [112]	validation_0-merror:0.025952
# [113]	validation_0-merror:0.025752
# [114]	validation_0-merror:0.025912
# [115]	validation_0-merror:0.025872
# [116]	validation_0-merror:0.025872
# [117]	validation_0-merror:0.025992
# [118]	validation_0-merror:0.025792
# [119]	validation_0-merror:0.025872
# [120]	validation_0-merror:0.025832
# [121]	validation_0-merror:0.025872
# [122]	validation_0-merror:0.025872
# [123]	validation_0-merror:0.025992
# [124]	validation_0-merror:0.026072
# [125]	validation_0-merror:0.026152
# [126]	validation_0-merror:0.026072
# [127]	validation_0-merror:0.026112
# [128]	validation_0-merror:0.025992
# [129]	validation_0-merror:0.025952
# [130]	validation_0-merror:0.025952
# [131]	validation_0-merror:0.026112
# [132]	validation_0-merror:0.026112
# [133]	validation_0-merror:0.026192
# Stopping. Best iteration:
# [113]	validation_0-merror:0.025752
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# yri
# Training logistic regression
# /usr/lib/python3.6/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# Training XGB
# [0]	validation_0-merror:0.059554
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.058438
# [2]	validation_0-merror:0.057647
# [3]	validation_0-merror:0.056949
# [4]	validation_0-merror:0.055693
# [5]	validation_0-merror:0.054902
# [6]	validation_0-merror:0.05425
# [7]	validation_0-merror:0.052947
# [8]	validation_0-merror:0.051877
# [9]	validation_0-merror:0.050761
# [10]	validation_0-merror:0.049504
# [11]	validation_0-merror:0.047271
# [12]	validation_0-merror:0.047178
# [13]	validation_0-merror:0.046062
# [14]	validation_0-merror:0.046155
# [15]	validation_0-merror:0.045736
# [16]	validation_0-merror:0.045131
# [17]	validation_0-merror:0.044759
# [18]	validation_0-merror:0.044154
# [19]	validation_0-merror:0.043782
# [20]	validation_0-merror:0.043363
# [21]	validation_0-merror:0.043177
# [22]	validation_0-merror:0.042758
# [23]	validation_0-merror:0.042293
# [24]	validation_0-merror:0.042619
# [25]	validation_0-merror:0.042293
# [26]	validation_0-merror:0.042014
# [27]	validation_0-merror:0.041688
# [28]	validation_0-merror:0.041223
# [29]	validation_0-merror:0.041083
# [30]	validation_0-merror:0.040711
# [31]	validation_0-merror:0.040664
# [32]	validation_0-merror:0.040153
# [33]	validation_0-merror:0.03992
# [34]	validation_0-merror:0.039594
# [35]	validation_0-merror:0.039176
# [36]	validation_0-merror:0.038943
# [37]	validation_0-merror:0.038896
# [38]	validation_0-merror:0.038757
# [39]	validation_0-merror:0.038431
# [40]	validation_0-merror:0.038198
# [41]	validation_0-merror:0.038105
# [42]	validation_0-merror:0.038059
# [43]	validation_0-merror:0.037733
# [44]	validation_0-merror:0.037733
# [45]	validation_0-merror:0.037454
# [46]	validation_0-merror:0.037408
# [47]	validation_0-merror:0.037361
# [48]	validation_0-merror:0.037314
# [49]	validation_0-merror:0.036942
# [50]	validation_0-merror:0.036803
# [51]	validation_0-merror:0.03671
# [52]	validation_0-merror:0.036663
# [53]	validation_0-merror:0.036617
# [54]	validation_0-merror:0.036337
# [55]	validation_0-merror:0.036198
# [56]	validation_0-merror:0.036151
# [57]	validation_0-merror:0.035919
# [58]	validation_0-merror:0.036105
# [59]	validation_0-merror:0.036012
# [60]	validation_0-merror:0.035779
# [61]	validation_0-merror:0.03564
# [62]	validation_0-merror:0.0355
# [63]	validation_0-merror:0.0355
# [64]	validation_0-merror:0.03564
# [65]	validation_0-merror:0.035267
# [66]	validation_0-merror:0.035221
# [67]	validation_0-merror:0.035174
# [68]	validation_0-merror:0.035128
# [69]	validation_0-merror:0.034942
# [70]	validation_0-merror:0.034895
# [71]	validation_0-merror:0.034895
# [72]	validation_0-merror:0.034709
# [73]	validation_0-merror:0.034662
# [74]	validation_0-merror:0.034476
# [75]	validation_0-merror:0.034383
# [76]	validation_0-merror:0.034337
# [77]	validation_0-merror:0.034244
# [78]	validation_0-merror:0.03443
# [79]	validation_0-merror:0.034337
# [80]	validation_0-merror:0.034476
# [81]	validation_0-merror:0.034337
# [82]	validation_0-merror:0.034337
# [83]	validation_0-merror:0.034383
# [84]	validation_0-merror:0.03429
# [85]	validation_0-merror:0.034383
# [86]	validation_0-merror:0.034244
# [87]	validation_0-merror:0.034197
# [88]	validation_0-merror:0.034104
# [89]	validation_0-merror:0.034151
# [90]	validation_0-merror:0.034197
# [91]	validation_0-merror:0.034383
# [92]	validation_0-merror:0.034523
# [93]	validation_0-merror:0.034383
# [94]	validation_0-merror:0.034383
# [95]	validation_0-merror:0.034337
# [96]	validation_0-merror:0.03443
# [97]	validation_0-merror:0.034337
# [98]	validation_0-merror:0.034383
# [99]	validation_0-merror:0.034383
# [100]	validation_0-merror:0.034337
# [101]	validation_0-merror:0.03429
# [102]	validation_0-merror:0.034244
# [103]	validation_0-merror:0.03443
# [104]	validation_0-merror:0.03429
# [105]	validation_0-merror:0.034383
# [106]	validation_0-merror:0.034244
# [107]	validation_0-merror:0.034337
# [108]	validation_0-merror:0.03429
# Stopping. Best iteration:
# [88]	validation_0-merror:0.034104
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /home/boi/research/ML-maternal-cell-contamination/python/confidence_intervals.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   lower_bound = contaminations - z*np.sqrt(contaminations*(1 - contaminations)/df_test[sample_name + '^DP'].values)
# /home/boi/research/ML-maternal-cell-contamination/python/confidence_intervals.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   upper_bound = contaminations + z*np.sqrt(contaminations*(1 - contaminations)/df_test[sample_name + '^DP'].values)

# %%
import pickle

with open("results_1vA.pickle", "wb") as f:
    pickle.dump(results_cum, f)
