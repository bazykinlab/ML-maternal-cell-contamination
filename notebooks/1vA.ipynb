# %%
import pandas as pd
import numpy as np

import sys
sys.path.insert(0, '../python')
from preprocessing import load_suffixes, prepare_input
from recalibrator import Recalibrator
from utils import match
from confidence_intervals import confidence_intervals

np.random.seed(64)

# %%
trios = ["ajt", "chd", "corpas", "yri"]

# Pre-processing. Uncomment during first run of the script, then
# comment to avoid re-computing

# for trio in trios:
#     data_dir = '../data/' + trio + '/'
#     df = load_suffixes(data_dir)
#     df.to_csv(trio + '.csv', index=False)

# %% [markdown]
# For each trio, construct a training set from the remaining trios and save the predictions into a dictionary.

# %%
results_cum = {}

for test in trios:
    results = {}
    df_train = pd.DataFrame()
    
    for train in trios:
        if train != test:
            df_train = df_train.append(pd.read_csv(train + '.csv'))

    df_train = df_train[::100]
    df_test = pd.read_csv(test + '.csv')    
    
    X_train = prepare_input(df_train, target_cols=['justchild^GT'])
    y_train = df_train['justchild^GT'].values
    X_test = prepare_input(df_test, target_cols=['justchild^GT'])
    y_test = df_test['justchild^GT'].values

    contaminations = df_test['contamination'].values
    contamination_values = list(sorted(np.unique(contaminations)))

    X_tests = {}
    y_tests = {}
    idx = {}

    for contamination in contamination_values:
        idx[contamination] = contaminations == contamination
        X_tests[contamination] = X_test[idx[contamination]]
        y_tests[contamination] = y_test[idx[contamination]]
    
    results['dp'] = df_test['abortus^DP'].values
    results['y_test'] = y_test
    results['preds_naive'] = df_test['abortus^GT'].values
    results['idx'] = idx

    r = Recalibrator()
    print(test)
    r.train(X_train, y_train)
    
    results['preds_meta'] = r.model_meta.predict(X_test)
    results['preds_lr'] = r.predict_lr(X_test)
    results['preds_xgb'] = r.predict_xgb(X_test)
    results['preds_ci'] = r.model_ci.predict(X_test)

    results_cum[test] = results
# Out:
# ajt
# Training logistic regression
# Training XGB
# [0]	validation_0-merror:0.058095
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.050833
# [2]	validation_0-merror:0.046561
# [3]	validation_0-merror:0.049551
# [4]	validation_0-merror:0.049551
# [5]	validation_0-merror:0.050406
# [6]	validation_0-merror:0.049551
# [7]	validation_0-merror:0.049551
# [8]	validation_0-merror:0.047416
# [9]	validation_0-merror:0.046988
# [10]	validation_0-merror:0.04528
# [11]	validation_0-merror:0.044853
# [12]	validation_0-merror:0.044425
# [13]	validation_0-merror:0.044425
# [14]	validation_0-merror:0.044425
# [15]	validation_0-merror:0.044425
# [16]	validation_0-merror:0.043998
# [17]	validation_0-merror:0.044425
# [18]	validation_0-merror:0.043571
# [19]	validation_0-merror:0.043998
# [20]	validation_0-merror:0.043998
# [21]	validation_0-merror:0.042717
# [22]	validation_0-merror:0.041435
# [23]	validation_0-merror:0.041435
# [24]	validation_0-merror:0.041435
# [25]	validation_0-merror:0.040581
# [26]	validation_0-merror:0.040154
# [27]	validation_0-merror:0.039727
# [28]	validation_0-merror:0.040154
# [29]	validation_0-merror:0.040154
# [30]	validation_0-merror:0.039727
# [31]	validation_0-merror:0.039727
# [32]	validation_0-merror:0.039727
# [33]	validation_0-merror:0.039299
# [34]	validation_0-merror:0.039299
# [35]	validation_0-merror:0.038872
# [36]	validation_0-merror:0.038872
# [37]	validation_0-merror:0.038872
# [38]	validation_0-merror:0.038445
# [39]	validation_0-merror:0.037591
# [40]	validation_0-merror:0.037591
# [41]	validation_0-merror:0.037591
# [42]	validation_0-merror:0.038018
# [43]	validation_0-merror:0.038018
# [44]	validation_0-merror:0.037164
# [45]	validation_0-merror:0.037164
# [46]	validation_0-merror:0.037164
# [47]	validation_0-merror:0.037164
# [48]	validation_0-merror:0.037164
# [49]	validation_0-merror:0.037164
# [50]	validation_0-merror:0.037164
# [51]	validation_0-merror:0.036736
# [52]	validation_0-merror:0.036736
# [53]	validation_0-merror:0.036309
# [54]	validation_0-merror:0.036309
# [55]	validation_0-merror:0.036736
# [56]	validation_0-merror:0.036736
# [57]	validation_0-merror:0.036736
# [58]	validation_0-merror:0.036309
# [59]	validation_0-merror:0.036309
# [60]	validation_0-merror:0.036309
# [61]	validation_0-merror:0.036309
# [62]	validation_0-merror:0.036309
# [63]	validation_0-merror:0.036309
# [64]	validation_0-merror:0.036309
# [65]	validation_0-merror:0.036309
# [66]	validation_0-merror:0.036309
# [67]	validation_0-merror:0.035882
# [68]	validation_0-merror:0.035028
# [69]	validation_0-merror:0.035028
# [70]	validation_0-merror:0.035882
# [71]	validation_0-merror:0.036309
# [72]	validation_0-merror:0.036736
# [73]	validation_0-merror:0.036736
# [74]	validation_0-merror:0.037164
# [75]	validation_0-merror:0.037591
# [76]	validation_0-merror:0.036736
# [77]	validation_0-merror:0.037591
# [78]	validation_0-merror:0.037164
# [79]	validation_0-merror:0.036309
# [80]	validation_0-merror:0.036309
# [81]	validation_0-merror:0.036736
# [82]	validation_0-merror:0.036736
# [83]	validation_0-merror:0.035455
# [84]	validation_0-merror:0.035455
# [85]	validation_0-merror:0.035882
# [86]	validation_0-merror:0.035882
# [87]	validation_0-merror:0.035455
# [88]	validation_0-merror:0.035882
# Stopping. Best iteration:
# [68]	validation_0-merror:0.035028
#
# Training meta-classifier
# ../python/confidence_intervals.py:37: RuntimeWarning: divide by zero encountered in true_divide
#   lower_bound = contaminations - self.z*np.sqrt(contaminations*(1 - contaminations)/dps)
# ../python/confidence_intervals.py:38: RuntimeWarning: divide by zero encountered in true_divide
#   upper_bound = contaminations + self.z*np.sqrt(contaminations*(1 - contaminations)/dps)
# ../python/confidence_intervals.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in greater
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:41: RuntimeWarning: invalid value encountered in true_divide
#   mo_share = (2*ab_ad1/dps)
# ../python/confidence_intervals.py:42: RuntimeWarning: invalid value encountered in greater
#   idx_0_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_0
# ../python/confidence_intervals.py:42: RuntimeWarning: invalid value encountered in less
#   idx_0_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_0
# ../python/confidence_intervals.py:45: RuntimeWarning: divide by zero encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in less
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:46: RuntimeWarning: invalid value encountered in true_divide
#   mo_share = (2*ab_ad0/dps)
# ../python/confidence_intervals.py:47: RuntimeWarning: invalid value encountered in greater
#   idx_1_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_1
# ../python/confidence_intervals.py:47: RuntimeWarning: invalid value encountered in less
#   idx_1_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_1
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# chd
# Training logistic regression
# Training XGB
# [0]	validation_0-merror:0.045271
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.038804
# [2]	validation_0-merror:0.038804
# [3]	validation_0-merror:0.04042
# [4]	validation_0-merror:0.038399
# [5]	validation_0-merror:0.037187
# [6]	validation_0-merror:0.037591
# [7]	validation_0-merror:0.037591
# [8]	validation_0-merror:0.037187
# [9]	validation_0-merror:0.036783
# [10]	validation_0-merror:0.036783
# [11]	validation_0-merror:0.037187
# [12]	validation_0-merror:0.036783
# [13]	validation_0-merror:0.036378
# [14]	validation_0-merror:0.035166
# [15]	validation_0-merror:0.034357
# [16]	validation_0-merror:0.034357
# [17]	validation_0-merror:0.033145
# [18]	validation_0-merror:0.033145
# [19]	validation_0-merror:0.03274
# [20]	validation_0-merror:0.032336
# [21]	validation_0-merror:0.031932
# [22]	validation_0-merror:0.030719
# [23]	validation_0-merror:0.031124
# [24]	validation_0-merror:0.030315
# [25]	validation_0-merror:0.030315
# [26]	validation_0-merror:0.030719
# [27]	validation_0-merror:0.030315
# [28]	validation_0-merror:0.029911
# [29]	validation_0-merror:0.029911
# [30]	validation_0-merror:0.029103
# [31]	validation_0-merror:0.029103
# [32]	validation_0-merror:0.028294
# [33]	validation_0-merror:0.027486
# [34]	validation_0-merror:0.027082
# [35]	validation_0-merror:0.026677
# [36]	validation_0-merror:0.027082
# [37]	validation_0-merror:0.027082
# [38]	validation_0-merror:0.025869
# [39]	validation_0-merror:0.025869
# [40]	validation_0-merror:0.026677
# [41]	validation_0-merror:0.026677
# [42]	validation_0-merror:0.026677
# [43]	validation_0-merror:0.026273
# [44]	validation_0-merror:0.026273
# [45]	validation_0-merror:0.025465
# [46]	validation_0-merror:0.025869
# [47]	validation_0-merror:0.025869
# [48]	validation_0-merror:0.025869
# [49]	validation_0-merror:0.025869
# [50]	validation_0-merror:0.025869
# [51]	validation_0-merror:0.025869
# [52]	validation_0-merror:0.025465
# [53]	validation_0-merror:0.025465
# [54]	validation_0-merror:0.025465
# [55]	validation_0-merror:0.025465
# [56]	validation_0-merror:0.025869
# [57]	validation_0-merror:0.025869
# [58]	validation_0-merror:0.025869
# [59]	validation_0-merror:0.025869
# [60]	validation_0-merror:0.025869
# [61]	validation_0-merror:0.025869
# [62]	validation_0-merror:0.025869
# [63]	validation_0-merror:0.025869
# [64]	validation_0-merror:0.025869
# [65]	validation_0-merror:0.025869
# Stopping. Best iteration:
# [45]	validation_0-merror:0.025465
#
# Training meta-classifier
# ../python/confidence_intervals.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: divide by zero encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# corpas
# Training logistic regression
# Training XGB
# [0]	validation_0-merror:0.062475
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.05847
# [2]	validation_0-merror:0.062875
# [3]	validation_0-merror:0.060072
# [4]	validation_0-merror:0.059672
# [5]	validation_0-merror:0.05807
# [6]	validation_0-merror:0.057669
# [7]	validation_0-merror:0.054065
# [8]	validation_0-merror:0.052062
# [9]	validation_0-merror:0.051262
# [10]	validation_0-merror:0.050461
# [11]	validation_0-merror:0.048058
# [12]	validation_0-merror:0.048859
# [13]	validation_0-merror:0.04966
# [14]	validation_0-merror:0.048458
# [15]	validation_0-merror:0.048058
# [16]	validation_0-merror:0.047257
# [17]	validation_0-merror:0.046456
# [18]	validation_0-merror:0.045655
# [19]	validation_0-merror:0.046055
# [20]	validation_0-merror:0.045254
# [21]	validation_0-merror:0.044453
# [22]	validation_0-merror:0.044053
# [23]	validation_0-merror:0.044453
# [24]	validation_0-merror:0.043252
# [25]	validation_0-merror:0.042451
# [26]	validation_0-merror:0.042451
# [27]	validation_0-merror:0.04205
# [28]	validation_0-merror:0.040449
# [29]	validation_0-merror:0.040449
# [30]	validation_0-merror:0.040048
# [31]	validation_0-merror:0.038847
# [32]	validation_0-merror:0.038446
# [33]	validation_0-merror:0.037645
# [34]	validation_0-merror:0.037645
# [35]	validation_0-merror:0.036844
# [36]	validation_0-merror:0.037245
# [37]	validation_0-merror:0.036444
# [38]	validation_0-merror:0.035643
# [39]	validation_0-merror:0.035643
# [40]	validation_0-merror:0.035242
# [41]	validation_0-merror:0.035242
# [42]	validation_0-merror:0.034842
# [43]	validation_0-merror:0.035242
# [44]	validation_0-merror:0.034842
# [45]	validation_0-merror:0.035242
# [46]	validation_0-merror:0.034842
# [47]	validation_0-merror:0.035643
# [48]	validation_0-merror:0.036043
# [49]	validation_0-merror:0.035643
# [50]	validation_0-merror:0.036043
# [51]	validation_0-merror:0.035643
# [52]	validation_0-merror:0.035643
# [53]	validation_0-merror:0.034441
# [54]	validation_0-merror:0.034041
# [55]	validation_0-merror:0.034041
# [56]	validation_0-merror:0.03324
# [57]	validation_0-merror:0.034041
# [58]	validation_0-merror:0.034041
# [59]	validation_0-merror:0.034441
# [60]	validation_0-merror:0.034441
# [61]	validation_0-merror:0.034041
# [62]	validation_0-merror:0.034441
# [63]	validation_0-merror:0.03364
# [64]	validation_0-merror:0.03324
# [65]	validation_0-merror:0.034041
# [66]	validation_0-merror:0.03364
# [67]	validation_0-merror:0.034041
# [68]	validation_0-merror:0.03364
# [69]	validation_0-merror:0.032839
# [70]	validation_0-merror:0.03324
# [71]	validation_0-merror:0.032839
# [72]	validation_0-merror:0.03324
# [73]	validation_0-merror:0.032839
# [74]	validation_0-merror:0.034041
# [75]	validation_0-merror:0.034441
# [76]	validation_0-merror:0.034041
# [77]	validation_0-merror:0.034041
# [78]	validation_0-merror:0.03364
# [79]	validation_0-merror:0.034041
# [80]	validation_0-merror:0.03364
# [81]	validation_0-merror:0.034041
# [82]	validation_0-merror:0.03364
# [83]	validation_0-merror:0.03364
# [84]	validation_0-merror:0.03364
# [85]	validation_0-merror:0.03364
# [86]	validation_0-merror:0.03364
# [87]	validation_0-merror:0.034041
# [88]	validation_0-merror:0.034041
# [89]	validation_0-merror:0.034041
# Stopping. Best iteration:
# [69]	validation_0-merror:0.032839
#
# Training meta-classifier
# ../python/confidence_intervals.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in greater
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: divide by zero encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in less
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# yri
# Training logistic regression
# Training XGB
# [0]	validation_0-merror:0.070698
# Will train until validation_0-merror hasn't improved in 20 rounds.
# [1]	validation_0-merror:0.066977
# [2]	validation_0-merror:0.060465
# [3]	validation_0-merror:0.058605
# [4]	validation_0-merror:0.056279
# [5]	validation_0-merror:0.057674
# [6]	validation_0-merror:0.05907
# [7]	validation_0-merror:0.057674
# [8]	validation_0-merror:0.057674
# [9]	validation_0-merror:0.057209
# [10]	validation_0-merror:0.056744
# [11]	validation_0-merror:0.055814
# [12]	validation_0-merror:0.055349
# [13]	validation_0-merror:0.054884
# [14]	validation_0-merror:0.053488
# [15]	validation_0-merror:0.054419
# [16]	validation_0-merror:0.053488
# [17]	validation_0-merror:0.052093
# [18]	validation_0-merror:0.051628
# [19]	validation_0-merror:0.051163
# [20]	validation_0-merror:0.053023
# [21]	validation_0-merror:0.053023
# [22]	validation_0-merror:0.053023
# [23]	validation_0-merror:0.052558
# [24]	validation_0-merror:0.051628
# [25]	validation_0-merror:0.050698
# [26]	validation_0-merror:0.049767
# [27]	validation_0-merror:0.048372
# [28]	validation_0-merror:0.047907
# [29]	validation_0-merror:0.048837
# [30]	validation_0-merror:0.048372
# [31]	validation_0-merror:0.048372
# [32]	validation_0-merror:0.047442
# [33]	validation_0-merror:0.048372
# [34]	validation_0-merror:0.047442
# [35]	validation_0-merror:0.047907
# [36]	validation_0-merror:0.047442
# [37]	validation_0-merror:0.047442
# [38]	validation_0-merror:0.047442
# [39]	validation_0-merror:0.046977
# [40]	validation_0-merror:0.046977
# [41]	validation_0-merror:0.046977
# [42]	validation_0-merror:0.046512
# [43]	validation_0-merror:0.046977
# [44]	validation_0-merror:0.046512
# [45]	validation_0-merror:0.046512
# [46]	validation_0-merror:0.046512
# [47]	validation_0-merror:0.047442
# [48]	validation_0-merror:0.047442
# [49]	validation_0-merror:0.046977
# [50]	validation_0-merror:0.046977
# [51]	validation_0-merror:0.046977
# [52]	validation_0-merror:0.047442
# [53]	validation_0-merror:0.045581
# [54]	validation_0-merror:0.046047
# [55]	validation_0-merror:0.047907
# [56]	validation_0-merror:0.047907
# [57]	validation_0-merror:0.046977
# [58]	validation_0-merror:0.046977
# [59]	validation_0-merror:0.047442
# [60]	validation_0-merror:0.047442
# [61]	validation_0-merror:0.046977
# [62]	validation_0-merror:0.046977
# [63]	validation_0-merror:0.047442
# [64]	validation_0-merror:0.047442
# [65]	validation_0-merror:0.046977
# [66]	validation_0-merror:0.047442
# [67]	validation_0-merror:0.046977
# [68]	validation_0-merror:0.047907
# [69]	validation_0-merror:0.046977
# [70]	validation_0-merror:0.046512
# [71]	validation_0-merror:0.046512
# [72]	validation_0-merror:0.046977
# [73]	validation_0-merror:0.045581
# Stopping. Best iteration:
# [53]	validation_0-merror:0.045581
#
# Training meta-classifier
# ../python/confidence_intervals.py:37: RuntimeWarning: divide by zero encountered in true_divide
#   lower_bound = contaminations - self.z*np.sqrt(contaminations*(1 - contaminations)/dps)
# ../python/confidence_intervals.py:38: RuntimeWarning: divide by zero encountered in true_divide
#   upper_bound = contaminations + self.z*np.sqrt(contaminations*(1 - contaminations)/dps)
# ../python/confidence_intervals.py:40: RuntimeWarning: divide by zero encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in true_divide
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:40: RuntimeWarning: invalid value encountered in greater
#   idx_0 = idx_hetero & (ab_ad0/ab_ad1 > mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:41: RuntimeWarning: invalid value encountered in true_divide
#   mo_share = (2*ab_ad1/dps)
# ../python/confidence_intervals.py:42: RuntimeWarning: invalid value encountered in greater
#   idx_0_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_0
# ../python/confidence_intervals.py:42: RuntimeWarning: invalid value encountered in less
#   idx_0_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_0
# ../python/confidence_intervals.py:45: RuntimeWarning: divide by zero encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in true_divide
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:45: RuntimeWarning: invalid value encountered in less
#   idx_1 = idx_hetero & (ab_ad0/ab_ad1 < mo_ad0/mo_ad1)
# ../python/confidence_intervals.py:46: RuntimeWarning: invalid value encountered in true_divide
#   mo_share = (2*ab_ad0/dps)
# ../python/confidence_intervals.py:47: RuntimeWarning: invalid value encountered in greater
#   idx_1_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_1
# ../python/confidence_intervals.py:47: RuntimeWarning: invalid value encountered in less
#   idx_1_confirmed = (mo_share > lower_bound) & (mo_share < upper_bound) & idx_1
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# /usr/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# Serialize and save the dictionary

# %%
import pickle

with open("results_1vA.pickle", "wb") as f:
    pickle.dump(results_cum, f)
